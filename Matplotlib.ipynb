# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x= np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#Functional Method
plt.plot(x,y, "--r")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y, "--r")
plt.subplot(1,2,2)
plt.plot(y,x,"-b")

# %%
#OO
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x,y, "r")
axes.set_xlabel("X-Axis")
axes.set_ylabel("Y-Axis")
axes.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig2 = plt.figure()

axes1 = fig2.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig2.add_axes([0.2, 0.4, 0.3, 0.3])

axes1.plot(x,y, "r")
axes1.set_xlabel("X-Axis")
axes1.set_ylabel("Y-Axis")
axes1.set_title("Plot1")

axes2.plot(y, x, "b")
axes2.set_xlabel("X-Axis")
axes2.set_ylabel("Y-Axis")
axes2.set_title("Plot2")
# Out:
# Text(0.5, 1.0, 'Plot2')

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x,y)
axes[1].plot(y,x,"r")

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019A4367BA90>,
# ...
#       dtype=object)

# %%
fig, axes = plt.subplots()

axes.plot(x, x**2,label = "X Squared")
axes.plot(x, x**3,label = "X Cube")

axes.legend(loc = 0)

# %% [markdown]
# # Stacked Bar Chart

# %%
#labels are the categories on the x axis
import matplotlib.pyplot as plt
# %matplotlib inline
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width = .4, label = "Men")
ax.bar(labels, women_means, width = .4, bottom = men_means, label = "Women")
#ax.bar(labels, men_means, width, yerr=men_std, label='Men')
#ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

# %% [markdown]
# # Grouped bar chart

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

#Putting labels is difficult
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2 ,men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()
print(x)
# Out:
# [0 1 2 3 4]
